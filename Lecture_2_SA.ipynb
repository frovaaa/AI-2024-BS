# %% [markdown]
# ## Artificial Intelligence (BSc) SA 2024-2025
#
# - Prof. Luca Gambardella
# - Fatima Ezzeddine ([`fatima.ezzeddine@usi.ch`](mailto:fatima.ezzeddine@usi.ch))<br>
#
# ---
#
# ## 2nd Lab
#
# What we are going to do today:
# - Simluated Annealing algorithm from scratch and using Mealpy

# %% [markdown]
# ### Simulated Annealing from Scratch

# %%
import numpy as np

from utils import compute_length, ProblemInstance, SolverTSP


def sa_swap2opt(tsp_sequence, i, j):
    new_tsp_sequence = np.copy(tsp_sequence)
    new_tsp_sequence[i : j + 1] = np.flip(
        tsp_sequence[i : j + 1], axis=0
    )  # flip or swap ?
    return new_tsp_sequence


def gain(i, j, tsp_sequence, matrix_dist):
    old_link_len = (
        matrix_dist[tsp_sequence[i], tsp_sequence[i - 1]]
        + matrix_dist[tsp_sequence[j], tsp_sequence[j + 1]]
    )
    changed_links_len = (
        matrix_dist[tsp_sequence[j], tsp_sequence[i - 1]]
        + matrix_dist[tsp_sequence[i], tsp_sequence[j + 1]]
    )
    return -old_link_len + changed_links_len


# genrate a random solution that is neighbor to the exisitng solution
def random_sol_from_neigh(solution, instance):
    # generate 2 random i and j
    i, j = np.random.choice(np.arange(1, len(solution) - 1), 2, replace=False)
    # sort i and j
    i, j = np.sort([i, j])
    solution = np.roll(solution, np.random.randint(len(solution)))
    # do an 2opt swap based on the 2 random i an j generated, and compute the gain of this 2opt
    return sa_swap2opt(solution, i, j), gain(i, j, solution, instance.dist_matrix)


def sa(solution, instance, constant_temperature=0.95, iterations_for_each_temp=100):
    # initial setup
    # initialize the temperature T = tmax
    temperature = instance.best_sol / np.sqrt(instance.nPoints)

    # initializing initial solution and len (x)
    current_sol = np.array(solution)
    # initial energey of x, E(x), energy is the tour length
    current_len = compute_length(solution, instance.dist_matrix)

    # variables to save the best sol
    best_sol = np.array(solution)
    best_len = current_len
    # main loop
    while temperature > 0.001:  # lowest accepted temeperature, T > Tmin and E > Eth
        # TODO
        # equilibrium for the current temperature, or specify max iteration for each temperature
        for it in range(iterations_for_each_temp):
            # generate new candidate solution from neighbors
            next_sol, deltaE = random_sol_from_neigh(current_sol, instance)
            # if neighbor solution is an improvment: accept it and save it in current and best solution variables
            if deltaE < 0:
                current_sol = next_sol
                current_len += deltaE
                if current_len < best_len:
                    best_sol = current_sol
                    best_len = current_len
            else:  # neighbor solution is not an improvment: compute exp(-deltaE/E) and generate a random number r in range [0, 1] and ecide if accept it or not
                r = np.random.uniform(0, 1)
                if r < np.exp(-deltaE / temperature):
                    current_sol = next_sol
                    current_len = current_len + deltaE

        # decrease temperature
        temperature *= constant_temperature
    # END TODO
    # return best tour solution
    return best_sol.tolist()

# %%
from time import time as t
from utils import (
    random_method,
)

available_solvers = {
    "random": random_method,
}

example_problem = "./TSP_problems/eil76.tsp"
p_inst = ProblemInstance(example_problem)

solver = SolverTSP("random", p_inst, available_solvers)
start = t()
solver.compute_solution(return_value=False, verbose=True)
end = t()

initial_solution = solver.solution

solver.plot_solution()
print(
    f"best solution with len {solver.found_length} \nwith a total time of {np.round(end - start, 5)} seconds"
)
print(f"solution found has a {solver.gap} % gap")

start = t()
solution = sa(solver.solution, p_inst)
end = t()
print(end - start)
solver.method = "SA"

# assert solver.pass_and_check_if_solution_is_valid(solution), "Solution non valid"
solver.solved = True
solver.solution = solution
solver.plot_solution()
solver._gap()
print(f"SA {solver.gap} % gap")
# Out:
# ###  solving with random  ####
# ###  solved  ####
# best solution with len 2614.0
# with a total time of 0.00291 seconds
# solution found has a 385.87 % gap
# 0.4516181945800781
# SA 9.11 % gap

# %%
# generate a random solution that is neighbor to the existng solution
def random_sol_from_neigh_mealpy(solution):
    # generate 2 random i and j
    i, j = np.random.choice(np.arange(1, len(solution) - 1), 2, replace=False)
    # sort i and j
    i, j = np.sort([i, j])
    solution = np.roll(solution, np.random.randint(len(solution)))
    # do an 2opt swap based on the 2 random i an j generated, and compute the gain of this 2opt
    return sa_swap2opt(solution, i, j)

def compute_gap(optimal, best_found):
    return np.round(((best_found - optimal) / optimal) * 100, 2)

# %%
from mealpy import PermutationVar, Problem, SA, GA, PSO, ACOR 
from mealpy.utils.agent import Agent

# Define the positions of the cities
# city_positions = np.array([[60, 200], [180, 200], [80, 180], [140, 180], [20, 160],
#                            [100, 160], [200, 160], [140, 140], [40, 120], [100, 120],
#                            [180, 100], [60, 80], [120, 80], [180, 60], [20, 40],
#                            [100, 40], [200, 40], [20, 20], [60, 20], [160, 20]])

# All the rows (x) and foreach row the 2nd and 3rd columns (x, y)
city_positions = p_inst.points[:, 1:3]

num_cities = len(city_positions)
data = {
    "city_positions": city_positions,
    "num_cities": num_cities,
}

class TspProblem(Problem):
    def __init__(self, bounds=None, minmax="min", data=None, **kwargs):
        self.data = data
        super().__init__(bounds, minmax, **kwargs)
        
                
    @staticmethod
    def calculate_distance(city_a, city_b):
        rounding = 0
        x_i, y_i = city_a[0], city_a[1]
        x_j, y_j = city_b[0], city_b[1]
        # use the numpy sqrt method
        distance = np.sqrt((x_i - x_j) ** 2 + (y_i - y_j) ** 2)
        return round(distance, rounding)

    @staticmethod
    def calculate_total_distance(route, city_positions):
        # Calculate total distance of a route
        total_distance = 0
        num_cities = len(route)
        for idx in range(num_cities):
            current_city = int(route[idx])
            next_city = int(route[(idx + 1) % num_cities])  # Wrap around to the first city
            total_distance += TspProblem.calculate_distance(city_positions[current_city], city_positions[next_city])
        return total_distance

    def obj_func(self, x):
        route = x
        fitness = self.calculate_total_distance(route, self.data["city_positions"])
        return fitness


# Custom Simulated Annealing class
# We have to change the way they implemented the perturbation and use the neighbor function we defined
# To solve the TSP problem with the Simulated Annealing algorithm
class CustomTSPSA(SA.OriginalSA):
    
    def __init__(self, epoch: int = 10000, pop_size: int = 2, temp_init: float = 100, step_size: float = 0.1,
                 **kwargs: object):
        super().__init__(epoch, pop_size, temp_init, step_size)

    
    def initialize_variables(self):
        print('Initializing TSP Agents...')
        self.g_best = Agent()
        self.g_best.solution = np.array(initial_solution)
        self.g_best.target = self.problem.get_target(self.g_best.solution)

        
    def generate_agent(self, solution: np.ndarray = None) -> Agent:
        """
        Generate new agent with full information

        Args:
            solution (np.ndarray): The solution
        """
        if solution is None:
            print('Initializing TSP solution...')
            solution = initial_solution
            agent = Agent(solution=solution, target=self.problem.get_target(solution))
            return agent
                
        agent = Agent(solution=solution, target=self.problem.get_target(solution))
           
        agent.solution = random_sol_from_neigh_mealpy(solution)
        # Objective function
        agent.target = problem.get_target(agent.solution)
        return agent
    
    
    def evolve(self, epoch):
        """
        The main operations (equations) of algorithm. Inherit from Optimizer class

        Args:
            epoch (int): The current iteration
        """
        # Perturb the current solution
        agent = self.generate_agent(self.agent_current.solution)
        # Accept or reject the new solution
        if self.compare_target(agent.target, self.agent_current.target, self.problem.minmax):
            self.agent_current = agent
        else:
            # Calculate the energy difference
            delta_energy = np.abs(self.agent_current.target.fitness - agent.target.fitness)
            # calculate probability acceptance criterion
            p_accept = np.exp(-delta_energy/ (self.temp_init / float(epoch + 1)))
            if self.generator.random() < p_accept:
                self.agent_current = agent
                
        self.pop = [self.g_best.copy(), self.agent_current.copy()]

# %%
bounds = PermutationVar(valid_set=list(range(0, num_cities)), name="per_var")
problem = TspProblem(bounds=bounds, minmax="min", data=data)

model = CustomTSPSA(epoch=5000, pop_size=2, temp_init = 100, step_size = 0.01)

g_best = model.solve(problem)

print(f"Solution: {g_best.solution}, Fitness: {g_best.target.fitness}")
print(f"Solution: {model.g_best.solution}, Fitness: {model.g_best.target.fitness}")

print(f"Best agent: {model.g_best}")                    # Encoded solution
print(f"Best solution: {model.g_best.solution}")        # Encoded solution
print(f"Best fitness: {model.g_best.target.fitness}")
print(f"Best real scheduling: {model.problem.decode_solution(model.g_best.solution)}")      # Decoded (Real) solution
# Out:
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: Solving single objective optimization problem.
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 1, Current best: 2614.0, Global best: 2614.0, Runtime: 0.00181 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 2, Current best: 2607.0, Global best: 2607.0, Runtime: 0.00077 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 3, Current best: 2607.0, Global best: 2607.0, Runtime: 0.00116 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4, Current best: 2592.0, Global best: 2592.0, Runtime: 0.00075 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 5, Current best: 2576.0, Global best: 2576.0, Runtime: 0.00119 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 6, Current best: 2561.0, Global best: 2561.0, Runtime: 0.00067 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 7, Current best: 2560.0, Global best: 2560.0, Runtime: 0.00063 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 8, Current best: 2560.0, Global best: 2560.0, Runtime: 0.00066 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 9, Current best: 2560.0, Global best: 2560.0, Runtime: 0.00160 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 10, Current best: 2552.0, Global best: 2552.0, Runtime: 0.00059 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 11, Current best: 2552.0, Global best: 2552.0, Runtime: 0.00058 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 12, Current best: 2552.0, Global best: 2552.0, Runtime: 0.00081 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 13, Current best: 2552.0, Global best: 2552.0, Runtime: 0.00056 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 14, Current best: 2551.0, Global best: 2551.0, Runtime: 0.00063 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 15, Current best: 2551.0, Global best: 2551.0, Runtime: 0.00091 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 16, Current best: 2534.0, Global best: 2534.0, Runtime: 0.00068 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 17, Current best: 2524.0, Global best: 2524.0, Runtime: 0.00062 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 18, Current best: 2524.0, Global best: 2524.0, Runtime: 0.00061 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 19, Current best: 2517.0, Global best: 2517.0, Runtime: 0.00062 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 20, Current best: 2517.0, Global best: 2517.0, Runtime: 0.00059 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 21, Current best: 2501.0, Global best: 2501.0, Runtime: 0.00076 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 22, Current best: 2474.0, Global best: 2474.0, Runtime: 0.00067 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 23, Current best: 2474.0, Global best: 2474.0, Runtime: 0.00070 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 24, Current best: 2467.0, Global best: 2467.0, Runtime: 0.00060 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 25, Current best: 2467.0, Global best: 2467.0, Runtime: 0.00063 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 26, Current best: 2457.0, Global best: 2457.0, Runtime: 0.00188 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 27, Current best: 2447.0, Global best: 2447.0, Runtime: 0.00050 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 28, Current best: 2439.0, Global best: 2439.0, Runtime: 0.00050 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 29, Current best: 2439.0, Global best: 2439.0, Runtime: 0.00046 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 30, Current best: 2439.0, Global best: 2439.0, Runtime: 0.00060 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 31, Current best: 2439.0, Global best: 2439.0, Runtime: 0.00063 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 32, Current best: 2434.0, Global best: 2434.0, Runtime: 0.00052 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 33, Current best: 2428.0, Global best: 2428.0, Runtime: 0.00073 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 34, Current best: 2359.0, Global best: 2359.0, Runtime: 0.00044 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 35, Current best: 2359.0, Global best: 2359.0, Runtime: 0.00043 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 36, Current best: 2359.0, Global best: 2359.0, Runtime: 0.00045 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 37, Current best: 2359.0, Global best: 2359.0, Runtime: 0.00044 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 38, Current best: 2359.0, Global best: 2359.0, Runtime: 0.00041 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 39, Current best: 2339.0, Global best: 2339.0, Runtime: 0.00041 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 40, Current best: 2329.0, Global best: 2329.0, Runtime: 0.00048 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 41, Current best: 2329.0, Global best: 2329.0, Runtime: 0.00051 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 42, Current best: 2306.0, Global best: 2306.0, Runtime: 0.00042 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 43, Current best: 2298.0, Global best: 2298.0, Runtime: 0.00040 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 44, Current best: 2290.0, Global best: 2290.0, Runtime: 0.00039 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 45, Current best: 2290.0, Global best: 2290.0, Runtime: 0.00043 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 46, Current best: 2280.0, Global best: 2280.0, Runtime: 0.00043 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 47, Current best: 2280.0, Global best: 2280.0, Runtime: 0.00041 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 48, Current best: 2276.0, Global best: 2276.0, Runtime: 0.00039 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 49, Current best: 2276.0, Global best: 2276.0, Runtime: 0.00038 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 50, Current best: 2276.0, Global best: 2276.0, Runtime: 0.00043 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 51, Current best: 2276.0, Global best: 2276.0, Runtime: 0.00041 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 52, Current best: 2276.0, Global best: 2276.0, Runtime: 0.00040 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 53, Current best: 2270.0, Global best: 2270.0, Runtime: 0.00040 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 54, Current best: 2270.0, Global best: 2270.0, Runtime: 0.00036 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 55, Current best: 2254.0, Global best: 2254.0, Runtime: 0.00035 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 56, Current best: 2254.0, Global best: 2254.0, Runtime: 0.00037 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 57, Current best: 2254.0, Global best: 2254.0, Runtime: 0.00036 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 58, Current best: 2254.0, Global best: 2254.0, Runtime: 0.00036 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 59, Current best: 2254.0, Global best: 2254.0, Runtime: 0.00038 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 60, Current best: 2254.0, Global best: 2254.0, Runtime: 0.00035 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 61, Current best: 2239.0, Global best: 2239.0, Runtime: 0.00089 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 62, Current best: 2239.0, Global best: 2239.0, Runtime: 0.00047 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 63, Current best: 2239.0, Global best: 2239.0, Runtime: 0.00049 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 64, Current best: 2239.0, Global best: 2239.0, Runtime: 0.00048 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 65, Current best: 2239.0, Global best: 2239.0, Runtime: 0.00040 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 66, Current best: 2239.0, Global best: 2239.0, Runtime: 0.00043 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 67, Current best: 2239.0, Global best: 2239.0, Runtime: 0.00054 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 68, Current best: 2220.0, Global best: 2220.0, Runtime: 0.00043 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 69, Current best: 2194.0, Global best: 2194.0, Runtime: 0.00037 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 70, Current best: 2194.0, Global best: 2194.0, Runtime: 0.00037 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 71, Current best: 2177.0, Global best: 2177.0, Runtime: 0.00037 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 72, Current best: 2177.0, Global best: 2177.0, Runtime: 0.00039 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 73, Current best: 2170.0, Global best: 2170.0, Runtime: 0.00040 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 74, Current best: 2170.0, Global best: 2170.0, Runtime: 0.00072 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 75, Current best: 2170.0, Global best: 2170.0, Runtime: 0.00054 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 76, Current best: 2170.0, Global best: 2170.0, Runtime: 0.00036 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 77, Current best: 2134.0, Global best: 2134.0, Runtime: 0.00036 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 78, Current best: 2134.0, Global best: 2134.0, Runtime: 0.00036 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 79, Current best: 2134.0, Global best: 2134.0, Runtime: 0.00038 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 80, Current best: 2112.0, Global best: 2112.0, Runtime: 0.00035 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 81, Current best: 2112.0, Global best: 2112.0, Runtime: 0.00098 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 82, Current best: 2112.0, Global best: 2112.0, Runtime: 0.00050 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 83, Current best: 2112.0, Global best: 2112.0, Runtime: 0.00038 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 84, Current best: 2112.0, Global best: 2112.0, Runtime: 0.00037 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 85, Current best: 2112.0, Global best: 2112.0, Runtime: 0.00042 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 86, Current best: 2112.0, Global best: 2112.0, Runtime: 0.00039 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 87, Current best: 2112.0, Global best: 2112.0, Runtime: 0.00036 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 88, Current best: 2112.0, Global best: 2112.0, Runtime: 0.00036 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 89, Current best: 2112.0, Global best: 2112.0, Runtime: 0.00035 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 90, Current best: 2112.0, Global best: 2112.0, Runtime: 0.00034 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 91, Current best: 2111.0, Global best: 2111.0, Runtime: 0.00035 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 92, Current best: 2111.0, Global best: 2111.0, Runtime: 0.00035 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 93, Current best: 2111.0, Global best: 2111.0, Runtime: 0.00034 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 94, Current best: 2111.0, Global best: 2111.0, Runtime: 0.00042 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 95, Current best: 2111.0, Global best: 2111.0, Runtime: 0.00039 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 96, Current best: 2066.0, Global best: 2066.0, Runtime: 0.00278 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 97, Current best: 2046.0, Global best: 2046.0, Runtime: 0.00171 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 98, Current best: 2046.0, Global best: 2046.0, Runtime: 0.00064 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 99, Current best: 2046.0, Global best: 2046.0, Runtime: 0.00053 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 100, Current best: 2046.0, Global best: 2046.0, Runtime: 0.00039 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 101, Current best: 2046.0, Global best: 2046.0, Runtime: 0.00037 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 102, Current best: 2040.0, Global best: 2040.0, Runtime: 0.00044 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 103, Current best: 2040.0, Global best: 2040.0, Runtime: 0.00038 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 104, Current best: 2040.0, Global best: 2040.0, Runtime: 0.00042 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 105, Current best: 2033.0, Global best: 2033.0, Runtime: 0.00036 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 106, Current best: 2033.0, Global best: 2033.0, Runtime: 0.00037 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 107, Current best: 2033.0, Global best: 2033.0, Runtime: 0.00036 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 108, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00035 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 109, Current best: 1954.0, Global best: 1954.0, Runtime: 0.00034 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 110, Current best: 1954.0, Global best: 1954.0, Runtime: 0.00035 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 111, Current best: 1947.0, Global best: 1947.0, Runtime: 0.00035 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 112, Current best: 1947.0, Global best: 1947.0, Runtime: 0.00033 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 113, Current best: 1936.0, Global best: 1936.0, Runtime: 0.00037 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 114, Current best: 1936.0, Global best: 1936.0, Runtime: 0.00049 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 115, Current best: 1936.0, Global best: 1936.0, Runtime: 0.00055 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 116, Current best: 1936.0, Global best: 1936.0, Runtime: 0.00038 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 117, Current best: 1936.0, Global best: 1936.0, Runtime: 0.00035 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 118, Current best: 1936.0, Global best: 1936.0, Runtime: 0.00038 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 119, Current best: 1936.0, Global best: 1936.0, Runtime: 0.00036 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 120, Current best: 1936.0, Global best: 1936.0, Runtime: 0.00054 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 121, Current best: 1936.0, Global best: 1936.0, Runtime: 0.00036 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 122, Current best: 1936.0, Global best: 1936.0, Runtime: 0.00036 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 123, Current best: 1936.0, Global best: 1936.0, Runtime: 0.00036 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 124, Current best: 1931.0, Global best: 1931.0, Runtime: 0.00033 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 125, Current best: 1892.0, Global best: 1892.0, Runtime: 0.00033 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 126, Current best: 1892.0, Global best: 1892.0, Runtime: 0.00033 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 127, Current best: 1892.0, Global best: 1892.0, Runtime: 0.00035 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 128, Current best: 1892.0, Global best: 1892.0, Runtime: 0.00034 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 129, Current best: 1892.0, Global best: 1892.0, Runtime: 0.00034 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 130, Current best: 1892.0, Global best: 1892.0, Runtime: 0.00034 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 131, Current best: 1865.0, Global best: 1865.0, Runtime: 0.00032 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 132, Current best: 1865.0, Global best: 1865.0, Runtime: 0.00034 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 133, Current best: 1865.0, Global best: 1865.0, Runtime: 0.00033 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 134, Current best: 1858.0, Global best: 1858.0, Runtime: 0.00033 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 135, Current best: 1846.0, Global best: 1846.0, Runtime: 0.00035 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 136, Current best: 1846.0, Global best: 1846.0, Runtime: 0.00036 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 137, Current best: 1846.0, Global best: 1846.0, Runtime: 0.03272 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 138, Current best: 1846.0, Global best: 1846.0, Runtime: 0.00128 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 139, Current best: 1812.0, Global best: 1812.0, Runtime: 0.00072 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 140, Current best: 1812.0, Global best: 1812.0, Runtime: 0.00039 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 141, Current best: 1807.0, Global best: 1807.0, Runtime: 0.00055 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 142, Current best: 1807.0, Global best: 1807.0, Runtime: 0.00041 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 143, Current best: 1807.0, Global best: 1807.0, Runtime: 0.00099 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 144, Current best: 1807.0, Global best: 1807.0, Runtime: 0.00120 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 145, Current best: 1782.0, Global best: 1782.0, Runtime: 0.00122 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 146, Current best: 1782.0, Global best: 1782.0, Runtime: 0.00072 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 147, Current best: 1771.0, Global best: 1771.0, Runtime: 0.00062 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 148, Current best: 1771.0, Global best: 1771.0, Runtime: 0.00037 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 149, Current best: 1771.0, Global best: 1771.0, Runtime: 0.00036 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 150, Current best: 1771.0, Global best: 1771.0, Runtime: 0.00038 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 151, Current best: 1771.0, Global best: 1771.0, Runtime: 0.00035 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 152, Current best: 1771.0, Global best: 1771.0, Runtime: 0.00035 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 153, Current best: 1771.0, Global best: 1771.0, Runtime: 0.00037 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 154, Current best: 1761.0, Global best: 1761.0, Runtime: 0.00037 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 155, Current best: 1761.0, Global best: 1761.0, Runtime: 0.00036 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 156, Current best: 1761.0, Global best: 1761.0, Runtime: 0.00040 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 157, Current best: 1761.0, Global best: 1761.0, Runtime: 0.00040 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 158, Current best: 1742.0, Global best: 1742.0, Runtime: 0.00035 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 159, Current best: 1742.0, Global best: 1742.0, Runtime: 0.00041 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 160, Current best: 1742.0, Global best: 1742.0, Runtime: 0.00034 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 161, Current best: 1742.0, Global best: 1742.0, Runtime: 0.00034 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 162, Current best: 1742.0, Global best: 1742.0, Runtime: 0.00035 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 163, Current best: 1742.0, Global best: 1742.0, Runtime: 0.00033 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 164, Current best: 1742.0, Global best: 1742.0, Runtime: 0.00034 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 165, Current best: 1742.0, Global best: 1742.0, Runtime: 0.00035 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 166, Current best: 1742.0, Global best: 1742.0, Runtime: 0.00035 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 167, Current best: 1742.0, Global best: 1742.0, Runtime: 0.00038 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 168, Current best: 1742.0, Global best: 1742.0, Runtime: 0.00070 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 169, Current best: 1742.0, Global best: 1742.0, Runtime: 0.00085 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 170, Current best: 1742.0, Global best: 1742.0, Runtime: 0.00060 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 171, Current best: 1742.0, Global best: 1742.0, Runtime: 0.00036 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 172, Current best: 1742.0, Global best: 1742.0, Runtime: 0.00036 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 173, Current best: 1742.0, Global best: 1742.0, Runtime: 0.00034 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 174, Current best: 1731.0, Global best: 1731.0, Runtime: 0.00035 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 175, Current best: 1731.0, Global best: 1731.0, Runtime: 0.00037 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 176, Current best: 1731.0, Global best: 1731.0, Runtime: 0.00035 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 177, Current best: 1731.0, Global best: 1731.0, Runtime: 0.00036 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 178, Current best: 1731.0, Global best: 1731.0, Runtime: 0.00035 seconds
# Initializing TSP Agents...
# Initializing TSP solution...
# Initializing TSP solution...
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 179, Current best: 1731.0, Global best: 1731.0, Runtime: 0.00034 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 180, Current best: 1731.0, Global best: 1731.0, Runtime: 0.00037 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 181, Current best: 1731.0, Global best: 1731.0, Runtime: 0.00034 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 182, Current best: 1731.0, Global best: 1731.0, Runtime: 0.00033 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 183, Current best: 1731.0, Global best: 1731.0, Runtime: 0.00036 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 184, Current best: 1731.0, Global best: 1731.0, Runtime: 0.00036 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 185, Current best: 1731.0, Global best: 1731.0, Runtime: 0.00042 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 186, Current best: 1731.0, Global best: 1731.0, Runtime: 0.00050 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 187, Current best: 1731.0, Global best: 1731.0, Runtime: 0.00049 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 188, Current best: 1731.0, Global best: 1731.0, Runtime: 0.00053 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 189, Current best: 1731.0, Global best: 1731.0, Runtime: 0.00158 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 190, Current best: 1731.0, Global best: 1731.0, Runtime: 0.00051 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 191, Current best: 1731.0, Global best: 1731.0, Runtime: 0.00037 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 192, Current best: 1731.0, Global best: 1731.0, Runtime: 0.00065 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 193, Current best: 1731.0, Global best: 1731.0, Runtime: 0.00059 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 194, Current best: 1731.0, Global best: 1731.0, Runtime: 0.00046 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 195, Current best: 1731.0, Global best: 1731.0, Runtime: 0.00038 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 196, Current best: 1703.0, Global best: 1703.0, Runtime: 0.00037 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 197, Current best: 1703.0, Global best: 1703.0, Runtime: 0.00036 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 198, Current best: 1696.0, Global best: 1696.0, Runtime: 0.00037 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 199, Current best: 1696.0, Global best: 1696.0, Runtime: 0.00034 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 200, Current best: 1696.0, Global best: 1696.0, Runtime: 0.00035 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 201, Current best: 1665.0, Global best: 1665.0, Runtime: 0.00035 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 202, Current best: 1665.0, Global best: 1665.0, Runtime: 0.00034 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 203, Current best: 1652.0, Global best: 1652.0, Runtime: 0.00033 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 204, Current best: 1646.0, Global best: 1646.0, Runtime: 0.00041 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 205, Current best: 1646.0, Global best: 1646.0, Runtime: 0.00042 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 206, Current best: 1646.0, Global best: 1646.0, Runtime: 0.00037 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 207, Current best: 1646.0, Global best: 1646.0, Runtime: 0.00036 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 208, Current best: 1646.0, Global best: 1646.0, Runtime: 0.00033 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 209, Current best: 1646.0, Global best: 1646.0, Runtime: 0.00037 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 210, Current best: 1646.0, Global best: 1646.0, Runtime: 0.00037 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 211, Current best: 1646.0, Global best: 1646.0, Runtime: 0.00036 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 212, Current best: 1646.0, Global best: 1646.0, Runtime: 0.00070 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 213, Current best: 1646.0, Global best: 1646.0, Runtime: 0.00048 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 214, Current best: 1646.0, Global best: 1646.0, Runtime: 0.00039 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 215, Current best: 1585.0, Global best: 1585.0, Runtime: 0.00036 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 216, Current best: 1585.0, Global best: 1585.0, Runtime: 0.00041 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 217, Current best: 1585.0, Global best: 1585.0, Runtime: 0.00039 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 218, Current best: 1585.0, Global best: 1585.0, Runtime: 0.00037 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 219, Current best: 1564.0, Global best: 1564.0, Runtime: 0.00035 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 220, Current best: 1564.0, Global best: 1564.0, Runtime: 0.00033 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 221, Current best: 1564.0, Global best: 1564.0, Runtime: 0.00033 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 222, Current best: 1564.0, Global best: 1564.0, Runtime: 0.00037 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 223, Current best: 1564.0, Global best: 1564.0, Runtime: 0.00034 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 224, Current best: 1564.0, Global best: 1564.0, Runtime: 0.00038 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 225, Current best: 1564.0, Global best: 1564.0, Runtime: 0.00034 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 226, Current best: 1564.0, Global best: 1564.0, Runtime: 0.00056 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 227, Current best: 1564.0, Global best: 1564.0, Runtime: 0.00038 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 228, Current best: 1564.0, Global best: 1564.0, Runtime: 0.00033 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 229, Current best: 1564.0, Global best: 1564.0, Runtime: 0.00034 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 230, Current best: 1564.0, Global best: 1564.0, Runtime: 0.00035 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 231, Current best: 1564.0, Global best: 1564.0, Runtime: 0.00035 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 232, Current best: 1564.0, Global best: 1564.0, Runtime: 0.00033 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 233, Current best: 1564.0, Global best: 1564.0, Runtime: 0.00035 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 234, Current best: 1564.0, Global best: 1564.0, Runtime: 0.00059 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 235, Current best: 1564.0, Global best: 1564.0, Runtime: 0.00053 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 236, Current best: 1564.0, Global best: 1564.0, Runtime: 0.00057 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 237, Current best: 1564.0, Global best: 1564.0, Runtime: 0.00041 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 238, Current best: 1559.0, Global best: 1559.0, Runtime: 0.00035 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 239, Current best: 1557.0, Global best: 1557.0, Runtime: 0.00046 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 240, Current best: 1557.0, Global best: 1557.0, Runtime: 0.00037 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 241, Current best: 1557.0, Global best: 1557.0, Runtime: 0.00043 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 242, Current best: 1557.0, Global best: 1557.0, Runtime: 0.00067 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 243, Current best: 1557.0, Global best: 1557.0, Runtime: 0.00057 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 244, Current best: 1557.0, Global best: 1557.0, Runtime: 0.00037 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 245, Current best: 1557.0, Global best: 1557.0, Runtime: 0.00033 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 246, Current best: 1546.0, Global best: 1546.0, Runtime: 0.00033 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 247, Current best: 1546.0, Global best: 1546.0, Runtime: 0.00033 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 248, Current best: 1546.0, Global best: 1546.0, Runtime: 0.00034 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 249, Current best: 1546.0, Global best: 1546.0, Runtime: 0.00034 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 250, Current best: 1546.0, Global best: 1546.0, Runtime: 0.00036 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 251, Current best: 1546.0, Global best: 1546.0, Runtime: 0.00033 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 252, Current best: 1546.0, Global best: 1546.0, Runtime: 0.00034 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 253, Current best: 1546.0, Global best: 1546.0, Runtime: 0.00040 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 254, Current best: 1546.0, Global best: 1546.0, Runtime: 0.00035 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 255, Current best: 1546.0, Global best: 1546.0, Runtime: 0.00041 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 256, Current best: 1546.0, Global best: 1546.0, Runtime: 0.00048 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 257, Current best: 1520.0, Global best: 1520.0, Runtime: 0.00041 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 258, Current best: 1520.0, Global best: 1520.0, Runtime: 0.00040 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 259, Current best: 1520.0, Global best: 1520.0, Runtime: 0.00048 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 260, Current best: 1520.0, Global best: 1520.0, Runtime: 0.00038 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 261, Current best: 1520.0, Global best: 1520.0, Runtime: 0.00035 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 262, Current best: 1520.0, Global best: 1520.0, Runtime: 0.00058 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 263, Current best: 1520.0, Global best: 1520.0, Runtime: 0.00036 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 264, Current best: 1520.0, Global best: 1520.0, Runtime: 0.00037 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 265, Current best: 1520.0, Global best: 1520.0, Runtime: 0.00032 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 266, Current best: 1520.0, Global best: 1520.0, Runtime: 0.00037 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 267, Current best: 1520.0, Global best: 1520.0, Runtime: 0.00044 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 268, Current best: 1520.0, Global best: 1520.0, Runtime: 0.00037 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 269, Current best: 1520.0, Global best: 1520.0, Runtime: 0.00040 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 270, Current best: 1520.0, Global best: 1520.0, Runtime: 0.00039 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 271, Current best: 1520.0, Global best: 1520.0, Runtime: 0.00032 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 272, Current best: 1520.0, Global best: 1520.0, Runtime: 0.00035 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 273, Current best: 1520.0, Global best: 1520.0, Runtime: 0.00033 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 274, Current best: 1520.0, Global best: 1520.0, Runtime: 0.00034 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 275, Current best: 1520.0, Global best: 1520.0, Runtime: 0.00033 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 276, Current best: 1520.0, Global best: 1520.0, Runtime: 0.00036 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 277, Current best: 1520.0, Global best: 1520.0, Runtime: 0.00035 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 278, Current best: 1520.0, Global best: 1520.0, Runtime: 0.00032 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 279, Current best: 1520.0, Global best: 1520.0, Runtime: 0.00035 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 280, Current best: 1520.0, Global best: 1520.0, Runtime: 0.00036 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 281, Current best: 1520.0, Global best: 1520.0, Runtime: 0.00037 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 282, Current best: 1520.0, Global best: 1520.0, Runtime: 0.00037 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 283, Current best: 1520.0, Global best: 1520.0, Runtime: 0.00053 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 284, Current best: 1520.0, Global best: 1520.0, Runtime: 0.00037 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 285, Current best: 1520.0, Global best: 1520.0, Runtime: 0.00043 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 286, Current best: 1520.0, Global best: 1520.0, Runtime: 0.00053 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 287, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00057 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 288, Current best: 1506.0, Global best: 1506.0, Runtime: 0.00039 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 289, Current best: 1506.0, Global best: 1506.0, Runtime: 0.00036 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 290, Current best: 1506.0, Global best: 1506.0, Runtime: 0.00034 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 291, Current best: 1504.0, Global best: 1504.0, Runtime: 0.00036 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 292, Current best: 1504.0, Global best: 1504.0, Runtime: 0.00040 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 293, Current best: 1497.0, Global best: 1497.0, Runtime: 0.00035 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 294, Current best: 1497.0, Global best: 1497.0, Runtime: 0.00034 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 295, Current best: 1497.0, Global best: 1497.0, Runtime: 0.00034 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 296, Current best: 1497.0, Global best: 1497.0, Runtime: 0.00033 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 297, Current best: 1493.0, Global best: 1493.0, Runtime: 0.00034 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 298, Current best: 1493.0, Global best: 1493.0, Runtime: 0.00035 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 299, Current best: 1493.0, Global best: 1493.0, Runtime: 0.00035 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 300, Current best: 1493.0, Global best: 1493.0, Runtime: 0.00037 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 301, Current best: 1493.0, Global best: 1493.0, Runtime: 0.00035 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 302, Current best: 1493.0, Global best: 1493.0, Runtime: 0.00046 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 303, Current best: 1490.0, Global best: 1490.0, Runtime: 0.00035 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 304, Current best: 1490.0, Global best: 1490.0, Runtime: 0.00039 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 305, Current best: 1431.0, Global best: 1431.0, Runtime: 0.00038 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 306, Current best: 1431.0, Global best: 1431.0, Runtime: 0.00034 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 307, Current best: 1431.0, Global best: 1431.0, Runtime: 0.00042 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 308, Current best: 1431.0, Global best: 1431.0, Runtime: 0.00055 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 309, Current best: 1431.0, Global best: 1431.0, Runtime: 0.00037 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 310, Current best: 1431.0, Global best: 1431.0, Runtime: 0.00036 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 311, Current best: 1431.0, Global best: 1431.0, Runtime: 0.00037 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 312, Current best: 1431.0, Global best: 1431.0, Runtime: 0.00038 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 313, Current best: 1431.0, Global best: 1431.0, Runtime: 0.00035 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 314, Current best: 1431.0, Global best: 1431.0, Runtime: 0.00034 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 315, Current best: 1431.0, Global best: 1431.0, Runtime: 0.00035 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 316, Current best: 1431.0, Global best: 1431.0, Runtime: 0.00040 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 317, Current best: 1431.0, Global best: 1431.0, Runtime: 0.00035 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 318, Current best: 1431.0, Global best: 1431.0, Runtime: 0.00044 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 319, Current best: 1431.0, Global best: 1431.0, Runtime: 0.00036 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 320, Current best: 1431.0, Global best: 1431.0, Runtime: 0.00034 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 321, Current best: 1431.0, Global best: 1431.0, Runtime: 0.00033 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 322, Current best: 1431.0, Global best: 1431.0, Runtime: 0.00033 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 323, Current best: 1431.0, Global best: 1431.0, Runtime: 0.00033 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 324, Current best: 1431.0, Global best: 1431.0, Runtime: 0.00035 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 325, Current best: 1431.0, Global best: 1431.0, Runtime: 0.00034 seconds
# 2024/10/14 10:31:58 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 326, Current best: 1431.0, Global best: 1431.0, Runtime: 0.00035 seconds
# ...
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4902, Current best: 628.0, Global best: 628.0, Runtime: 0.00034 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4903, Current best: 628.0, Global best: 628.0, Runtime: 0.00034 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4904, Current best: 628.0, Global best: 628.0, Runtime: 0.00037 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4905, Current best: 628.0, Global best: 628.0, Runtime: 0.00034 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4906, Current best: 628.0, Global best: 628.0, Runtime: 0.00035 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4907, Current best: 628.0, Global best: 628.0, Runtime: 0.00034 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4908, Current best: 628.0, Global best: 628.0, Runtime: 0.00034 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4909, Current best: 628.0, Global best: 628.0, Runtime: 0.00034 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4910, Current best: 628.0, Global best: 628.0, Runtime: 0.00035 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4911, Current best: 628.0, Global best: 628.0, Runtime: 0.00035 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4912, Current best: 628.0, Global best: 628.0, Runtime: 0.00036 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4913, Current best: 628.0, Global best: 628.0, Runtime: 0.00034 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4914, Current best: 628.0, Global best: 628.0, Runtime: 0.00034 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4915, Current best: 628.0, Global best: 628.0, Runtime: 0.00034 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4916, Current best: 628.0, Global best: 628.0, Runtime: 0.00034 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4917, Current best: 628.0, Global best: 628.0, Runtime: 0.00038 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4918, Current best: 628.0, Global best: 628.0, Runtime: 0.00098 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4919, Current best: 628.0, Global best: 628.0, Runtime: 0.00059 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4920, Current best: 628.0, Global best: 628.0, Runtime: 0.00061 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4921, Current best: 628.0, Global best: 628.0, Runtime: 0.00041 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4922, Current best: 628.0, Global best: 628.0, Runtime: 0.00040 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4923, Current best: 628.0, Global best: 628.0, Runtime: 0.00046 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4924, Current best: 628.0, Global best: 628.0, Runtime: 0.00056 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4925, Current best: 628.0, Global best: 628.0, Runtime: 0.00040 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4926, Current best: 628.0, Global best: 628.0, Runtime: 0.00037 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4927, Current best: 628.0, Global best: 628.0, Runtime: 0.00037 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4928, Current best: 628.0, Global best: 628.0, Runtime: 0.00039 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4929, Current best: 628.0, Global best: 628.0, Runtime: 0.00043 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4930, Current best: 628.0, Global best: 628.0, Runtime: 0.00033 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4931, Current best: 628.0, Global best: 628.0, Runtime: 0.00036 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4932, Current best: 628.0, Global best: 628.0, Runtime: 0.00034 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4933, Current best: 628.0, Global best: 628.0, Runtime: 0.00038 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4934, Current best: 628.0, Global best: 628.0, Runtime: 0.00046 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4935, Current best: 628.0, Global best: 628.0, Runtime: 0.00044 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4936, Current best: 628.0, Global best: 628.0, Runtime: 0.00035 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4937, Current best: 628.0, Global best: 628.0, Runtime: 0.00035 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4938, Current best: 628.0, Global best: 628.0, Runtime: 0.00034 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4939, Current best: 628.0, Global best: 628.0, Runtime: 0.00034 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4940, Current best: 628.0, Global best: 628.0, Runtime: 0.00036 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4941, Current best: 628.0, Global best: 628.0, Runtime: 0.00034 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4942, Current best: 628.0, Global best: 628.0, Runtime: 0.00034 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4943, Current best: 628.0, Global best: 628.0, Runtime: 0.00033 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4944, Current best: 628.0, Global best: 628.0, Runtime: 0.00035 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4945, Current best: 628.0, Global best: 628.0, Runtime: 0.00034 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4946, Current best: 628.0, Global best: 628.0, Runtime: 0.00033 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4947, Current best: 628.0, Global best: 628.0, Runtime: 0.00035 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4948, Current best: 628.0, Global best: 628.0, Runtime: 0.00035 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4949, Current best: 628.0, Global best: 628.0, Runtime: 0.00036 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4950, Current best: 628.0, Global best: 628.0, Runtime: 0.00034 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4951, Current best: 628.0, Global best: 628.0, Runtime: 0.00034 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4952, Current best: 628.0, Global best: 628.0, Runtime: 0.00035 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4953, Current best: 628.0, Global best: 628.0, Runtime: 0.00035 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4954, Current best: 628.0, Global best: 628.0, Runtime: 0.00035 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4955, Current best: 628.0, Global best: 628.0, Runtime: 0.00033 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4956, Current best: 628.0, Global best: 628.0, Runtime: 0.00034 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4957, Current best: 628.0, Global best: 628.0, Runtime: 0.00034 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4958, Current best: 628.0, Global best: 628.0, Runtime: 0.00035 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4959, Current best: 628.0, Global best: 628.0, Runtime: 0.00035 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4960, Current best: 628.0, Global best: 628.0, Runtime: 0.00035 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4961, Current best: 628.0, Global best: 628.0, Runtime: 0.00039 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4962, Current best: 628.0, Global best: 628.0, Runtime: 0.00042 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4963, Current best: 628.0, Global best: 628.0, Runtime: 0.00034 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4964, Current best: 628.0, Global best: 628.0, Runtime: 0.00038 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4965, Current best: 628.0, Global best: 628.0, Runtime: 0.00038 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4966, Current best: 621.0, Global best: 621.0, Runtime: 0.00034 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4967, Current best: 621.0, Global best: 621.0, Runtime: 0.00035 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4968, Current best: 621.0, Global best: 621.0, Runtime: 0.00037 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4969, Current best: 621.0, Global best: 621.0, Runtime: 0.00041 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4970, Current best: 621.0, Global best: 621.0, Runtime: 0.00034 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4971, Current best: 621.0, Global best: 621.0, Runtime: 0.00035 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4972, Current best: 621.0, Global best: 621.0, Runtime: 0.00036 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4973, Current best: 621.0, Global best: 621.0, Runtime: 0.00037 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4974, Current best: 621.0, Global best: 621.0, Runtime: 0.00065 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4975, Current best: 621.0, Global best: 621.0, Runtime: 0.00044 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4976, Current best: 621.0, Global best: 621.0, Runtime: 0.00075 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4977, Current best: 621.0, Global best: 621.0, Runtime: 0.00042 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4978, Current best: 621.0, Global best: 621.0, Runtime: 0.00035 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4979, Current best: 621.0, Global best: 621.0, Runtime: 0.00040 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4980, Current best: 621.0, Global best: 621.0, Runtime: 0.00065 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4981, Current best: 621.0, Global best: 621.0, Runtime: 0.00042 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4982, Current best: 621.0, Global best: 621.0, Runtime: 0.00036 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4983, Current best: 621.0, Global best: 621.0, Runtime: 0.00037 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4984, Current best: 621.0, Global best: 621.0, Runtime: 0.00036 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4985, Current best: 621.0, Global best: 621.0, Runtime: 0.00037 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4986, Current best: 621.0, Global best: 621.0, Runtime: 0.00430 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4987, Current best: 621.0, Global best: 621.0, Runtime: 0.01427 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4988, Current best: 621.0, Global best: 621.0, Runtime: 0.00044 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4989, Current best: 621.0, Global best: 621.0, Runtime: 0.00037 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4990, Current best: 621.0, Global best: 621.0, Runtime: 0.00039 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4991, Current best: 621.0, Global best: 621.0, Runtime: 0.00068 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4992, Current best: 621.0, Global best: 621.0, Runtime: 0.00062 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4993, Current best: 621.0, Global best: 621.0, Runtime: 0.00360 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4994, Current best: 621.0, Global best: 621.0, Runtime: 0.00298 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4995, Current best: 621.0, Global best: 621.0, Runtime: 0.00043 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4996, Current best: 621.0, Global best: 621.0, Runtime: 0.00035 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4997, Current best: 621.0, Global best: 621.0, Runtime: 0.00037 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4998, Current best: 621.0, Global best: 621.0, Runtime: 0.00036 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 4999, Current best: 621.0, Global best: 621.0, Runtime: 0.00046 seconds
# 2024/10/14 10:32:05 AM, INFO, __main__.CustomTSPSA: >>>Problem: P, Epoch: 5000, Current best: 621.0, Global best: 621.0, Runtime: 0.00040 seconds
# Solution: [20 47  3 74 67  5 32 62 50 39 71 57 11 16 25 75 66 45 33  7 51 26 12 53
#  18 52  6 34 13 58 10 65 64 37  9 30 38  8 24 17 54 49 31 43  2 15 48 23
#  22 55 42 40 41 63 21  0 72 61 27 73  1 29 28 44  4 14 56 36 19 69 59 70
#  35 68 60 46], Fitness: 621.0
# Solution: [20 47  3 74 67  5 32 62 50 39 71 57 11 16 25 75 66 45 33  7 51 26 12 53
#  18 52  6 34 13 58 10 65 64 37  9 30 38  8 24 17 54 49 31 43  2 15 48 23
#  22 55 42 40 41 63 21  0 72 61 27 73  1 29 28 44  4 14 56 36 19 69 59 70
#  35 68 60 46], Fitness: 621.0
# Best agent: id: 25010, target: Objectives: [621.], Fitness: 621.0, solution: [20 47  3 74 67  5 32 62 50 39 71 57 11 16 25 75 66 45 33  7 51 26 12 53
#  18 52  6 34 13 58 10 65 64 37  9 30 38  8 24 17 54 49 31 43  2 15 48 23
#  22 55 42 40 41 63 21  0 72 61 27 73  1 29 28 44  4 14 56 36 19 69 59 70
#  35 68 60 46]
# Best solution: [20 47  3 74 67  5 32 62 50 39 71 57 11 16 25 75 66 45 33  7 51 26 12 53
#  18 52  6 34 13 58 10 65 64 37  9 30 38  8 24 17 54 49 31 43  2 15 48 23
#  22 55 42 40 41 63 21  0 72 61 27 73  1 29 28 44  4 14 56 36 19 69 59 70
#  35 68 60 46]
# Best fitness: 621.0
# Best real scheduling: {'per_var': [55, 60, 44, 2, 64, 5, 26, 19, 37, 34, 30, 12, 22, 28, 65, 45, 13, 39, 24, 68, 0, 54, 48, 47, 38, 14, 21, 58, 62, 61, 35, 42, 6, 18, 27, 72, 67, 33, 36, 9, 51, 52, 50, 43, 63, 17, 75, 1, 46, 41, 8, 20, 25, 23, 40, 49, 66, 11, 29, 70, 74, 57, 7, 53, 32, 31, 16, 4, 73, 69, 71, 10, 56, 59, 3, 15]}

# %%
gap = compute_gap(p_inst.best_sol, model.g_best.target.fitness)
gap
# Out:
# np.float64(15.43)

# %%
model.g_best.target.fitness, p_inst.best_sol
# Out:
# (np.float64(621.0), 538.0)
